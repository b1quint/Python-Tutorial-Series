# %% [markdown]
# # PTS2019 - Data Analysis and Visualization 1

# %% [markdown]
# This notebook is part of the Python Tutorial Series presented in the Gemini Observatory. It will contain the basics on how to use Jupyter, NumPy and MatPlotLib.
#
# Here is the table of contents:

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Using-Jupyter" data-toc-modified-id="Using-Jupyter-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Using Jupyter</a></span><ul class="toc-item"><li><span><a href="#Quick-Reference" data-toc-modified-id="Quick-Reference-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Quick Reference</a></span></li><li><span><a href="#Jupyter-and-Markdown" data-toc-modified-id="Jupyter-and-Markdown-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Jupyter and Markdown</a></span></li><li><span><a href="#Jupyter-and-Python" data-toc-modified-id="Jupyter-and-Python-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Jupyter and Python</a></span></li><li><span><a href="#Warning" data-toc-modified-id="Warning-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Warning</a></span></li></ul></li><li><span><a href="#Starting-with-NumPy" data-toc-modified-id="Starting-with-NumPy-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Starting with NumPy</a></span><ul class="toc-item"><li><span><a href="#NumPy-and-Pythonic-ways" data-toc-modified-id="NumPy-and-Pythonic-ways-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>NumPy and Pythonic ways</a></span></li></ul></li><li><span><a href="#MatPlotLib" data-toc-modified-id="MatPlotLib-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>MatPlotLib</a></span><ul class="toc-item"><li><span><a href="#A-simple-plot" data-toc-modified-id="A-simple-plot-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>A simple plot</a></span></li><li><span><a href="#Basic-Customization" data-toc-modified-id="Basic-Customization-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Basic Customization</a></span></li><li><span><a href="#Customizing-default-parameters" data-toc-modified-id="Customizing-default-parameters-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Customizing default parameters</a></span></li><li><span><a href="#Using-styles" data-toc-modified-id="Using-styles-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Using styles</a></span></li><li><span><a href="#MatPlotLib-and-Jupyter" data-toc-modified-id="MatPlotLib-and-Jupyter-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>MatPlotLib and Jupyter</a></span></li><li><span><a href="#Working-with-Figures-and-Axes" data-toc-modified-id="Working-with-Figures-and-Axes-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Working with Figures and Axes</a></span></li><li><span><a href="#Plot-Types" data-toc-modified-id="Plot-Types-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Plot Types</a></span><ul class="toc-item"><li><span><a href="#Scatter-Plot" data-toc-modified-id="Scatter-Plot-3.7.1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Scatter Plot</a></span></li><li><span><a href="#Histograms" data-toc-modified-id="Histograms-3.7.2"><span class="toc-item-num">3.7.2&nbsp;&nbsp;</span>Histograms</a></span></li><li><span><a href="#Error-bars" data-toc-modified-id="Error-bars-3.7.3"><span class="toc-item-num">3.7.3&nbsp;&nbsp;</span>Error bars</a></span></li><li><span><a href="#More" data-toc-modified-id="More-3.7.4"><span class="toc-item-num">3.7.4&nbsp;&nbsp;</span>More</a></span></li></ul></li></ul></li><li><span><a href="#Wrapping-Up" data-toc-modified-id="Wrapping-Up-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Wrapping Up</a></span><ul class="toc-item"><li><span><a href="#Reading-the-data" data-toc-modified-id="Reading-the-data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Reading the data</a></span></li><li><span><a href="#First-Plot" data-toc-modified-id="First-Plot-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>First Plot</a></span></li><li><span><a href="#Changing-Marker-and-LineStyle" data-toc-modified-id="Changing-Marker-and-LineStyle-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Changing Marker and LineStyle</a></span></li><li><span><a href="#Adding-Labels-and-Title" data-toc-modified-id="Adding-Labels-and-Title-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Adding Labels and Title</a></span></li><li><span><a href="#Linear-Fitting" data-toc-modified-id="Linear-Fitting-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Linear Fitting</a></span></li><li><span><a href="#Plotting-ratio" data-toc-modified-id="Plotting-ratio-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Plotting ratio</a></span></li><li><span><a href="#Adding-a-Violin-Plot" data-toc-modified-id="Adding-a-Violin-Plot-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Adding a Violin Plot</a></span></li><li><span><a href="#Using-Scatter-plot" data-toc-modified-id="Using-Scatter-plot-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Using Scatter plot</a></span><ul class="toc-item"><li><span><a href="#with-different-marker-sizes" data-toc-modified-id="with-different-marker-sizes-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>with different marker sizes</a></span></li><li><span><a href="#with-different-colors" data-toc-modified-id="with-different-colors-4.8.2"><span class="toc-item-num">4.8.2&nbsp;&nbsp;</span>with different colors</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Using Jupyter

# %% [markdown]
# First of all, you must know that Jupyter has two modes: Command Mode and Edit Mode (just like `vim`).
#
# When you open or create a new notebook, you are on **edit mode**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# If you press `ESC`, you will jump into the **command mode**.
#
# ![image.png](attachment:image.png)
#
# If you, now, press `ENTER`, you will go back to the **edit mode**.

# %% [markdown]
# You can press `SHIFT + ENTER` to run each cell a move to the cell below.

# %% [markdown]
# ### Quick Reference
#
# Now that you know how to go from one to another mode, try to look what are the other keys available on Jupyter by typing `H` in **command mode**.

# %% [markdown]
# ### Jupyter and Markdown
#
# Jupyter is divided by cells and each cell can be edited in Python or Markdown, a markup language that makes it easy to write your own notes. Markdown allows *italic*, **bold**, $L^aTe_X$, [external hiperlinks](https://en.wikipedia.org/wiki/Markdown), `inline codes`,
#
# ```python
# import this
# print("Block Code")
# ```
#
# 1. Ordered
# 2. List
#
#     * Unordered
#     * List
#
# <a href="https://en.wikipedia.org/wiki/Markdown">My HTML Hyperlink</a>

# %% [markdown]
# More [here](https://www.markdownguide.org/cheat-sheet)!!

# %% [markdown]
# In order to enable edition in Markdown, you must be in **Command Mode** and press the **m** key.

# %% [markdown]
# ### Jupyter and Python

# %% [markdown]
# Jupyter allows you to use the notebook as a Python terminal too. To do so, simply go to **Command Mode** and press the **Y** key. You should see something like this:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Again, the green color indicates that you are in Edit Mode and the `In [ ]:` indicates that you can input some Python code.

# %% [markdown]
# ### Warning
#
# There are a few thing in Jupyter that should be used carefully or you will messing up things very easily.
#
# 1) The order of the cells might not match the execution order.
#
# 2) A variable defined in a cell that was deleted will still be stored in memory until the kernel is restarted.
#
# 3) You can share variables with **ANY** cell (even previous ones).

# %% [markdown]
# ## Starting with NumPy
#
# If you installed Astroconda, you have most of the libraries needed to process your data (but not all). To make sure you have it, you can try to import it:

# %%
import numpy as np

# %%
x_array = np.arange(-1, 6)
y_array = x_array ** 2

print(x_array)
print(y_array)
# Out:
# [-1  0  1  2  3  4  5]
# [ 1  0  1  4  9 16 25]

# %% [markdown]
# Each array comes with a set of handful methods. You can use the `TAB` completion to check all the possible options.
#
# Exercise:
#
# - Write `y_array.` in the cell below and press `TAB` right after you type the `.`.
# - A small window will pop-up. Use the keyboard arrows to navigate to a method.
# - Press `ENTER` to select a method.
# - Type `?` right after the name of this method and press `SHIFT + ENTER` to check the documentation.

# %% [markdown]
# Here are some useful methods:

# %%
y_array.mean()
# Out:
# 8.0

# %%
y_array.min()
# Out:
# 0

# %%
y_array.max()
# Out:
# 25

# %%
y_array.std()
# Out:
# 8.717797887081348

# %%
y_array.argmin()
# Out:
# 1

# %% [markdown]
# ### NumPy and Pythonic ways

# %%
# %%timeit
x_list = range(-1, 6)
y_list = []
for x in x_list:
    y_list.append(x ** 2)
# Out:
# 2.01 µs ± 54.8 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
x_list = range(-1, 6)
y_list = [x ** 2 for x in x_list]
# Out:
# 1.86 µs ± 25.7 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit
x_array = np.arange(-1, 6)
y_array = x_array ** 2
# Out:
# 1.17 µs ± 22.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## MatPlotLib

# %% [markdown]
# ### A simple plot

# %% [markdown]
# Now that we know that we can do some maths easily using `numpy`, let us
# do some simple plots.

# %%
from matplotlib.pyplot import *

plot(x_array, y_array)
show()

# %% [markdown]
# But we are **strongly** recommended to avoid the syntax above. The `from ... import *` goes against the Zen of Python since the imported functions are not explicit. You don't know what you are bringing and you might lose data. **Avoid this syntax at any cost!!**
#
# An option commonly used is to use the `from ... import ... as ...` syntax. This way you keep the relationship between functions, variables, classes explicitly. Check below:

# %%
from matplotlib import pyplot as plt

plt.plot(x_array, y_array)
plt.show()

# %% [markdown]
# ### Basic Customization
#
# You can easily customize most of the features in a MatPlotLib plot.

# %%
plt.plot(x_array, y_array, label='blue line')
plt.plot(x_array, y_array, 'C3o', label='circles')

plt.grid(alpha=0.25)
plt.legend(loc='best')

plt.xlabel('X')
plt.ylabel('Y')

_ = plt.title('My Plot')

# %% [markdown]
# ### Customizing default parameters

# %% [markdown]
# You can also change the plots behaviours using `plt.rcParams.update`:

# %%
plt.rcParams.update({'font.size': 22})

plt.plot(x_array, y_array, label='blue line')
plt.plot(x_array, y_array, 'o', label='circles')

plt.grid(alpha=0.25)
plt.legend(loc='best')

plt.xlabel('X')
plt.ylabel('Y')

plt.title('My Plot')
plt.show()

plt.rcParams.update({'font.size': 14})

# %% [markdown]
# ### Using styles
#
# MatPlotLib allows changing the style of the plots by simply using the `ply.style.context` **context manager**. Here is an example:

# %%
with plt.style.context('seaborn'):

    plt.figure(dpi=300)
    plt.plot(x_array, y_array, label='blue line')
    plt.plot(x_array, y_array, 'o', label='circles')

    plt.grid()
    plt.legend(loc='best')

    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('My Plot')

    plt.show()

# %% [markdown]
# Or, alternatively, you can use the `plt.style.use` function but that will change the style of all future plots.

# %%
plt.style.use('ggplot')

plt.plot(x_array, y_array, label='blue line')
plt.plot(x_array, y_array, 'o', label='circles')

plt.grid()
plt.legend(loc='best')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('My Plot')

plt.show()

# %% [markdown]
# ### MatPlotLib and Jupyter
#
# You can have interactive plots by adding `%matplotlib notebook` at the beginning of a cell. This allows zooming, paning, etc.:

# %%
# %matplotlib notebook

plt.style.use('default')

plt.plot(x_array, y_array, label='blue line')
plt.plot(x_array, y_array, 'o', label='circles')

plt.grid()
plt.legend(loc='best')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('My Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# The problem here is that any new plot will be added to the existing Figure. Run the code below and check it out:

# %%
plt.scatter([0, 1, 2, 3], [15, 20, 15, 20])

# %% [markdown]
# To avoid this behaviour, you can create a new figure using `plt.figure()`. This function accepts a `fignumber` argument that can be a string or an integer. This can be used to set what figure will be updated on the next `plt` command.
#
# Another option is to turn off the interactive more by adding `%matplotlib inline` at the beginning of a cell:

# %%
# %matplotlib inline
plt.scatter([0, 1, 2, 3], [15, 20, 15, 20])
plt.show()

# %% [markdown]
# ### Working with Figures and Axes
#
# Most of the MatPlotLib documetation is based on manipulating `Figures`, `Axes` and other elements directly instead of via `plt` module. Because of that, it is critical to have a good understanding of what they mean. Here we will re-do the same plot using this syntax:

# %%
my_figure, my_axes = plt.subplots()

my_axes.plot(x_array, y_array, label='blue line')
my_axes.plot(x_array, y_array, 'o', label='circles')

my_axes.grid(alpha=0.25)
my_axes.legend(loc='best')

my_axes.set_xlabel('X')
my_axes.set_ylabel('Y')
my_axes.set_title('My Plot')

plt.show()

# %% [markdown]
# ### Plot Types

# %% [markdown]
# MatPlotLib has all sorts of graphics available. Here are some examples:

# %% [markdown]
# #### Scatter Plot

# %%
np.random.seed(0)

x1 = np.random.normal(loc=0.5, scale=0.1, size=100)
y1 = np.random.normal(loc=0.5, scale=0.1, size=100)
z1 = np.random.random(100) * 200

x2 = np.random.normal(loc=0.75, scale=0.1, size=100)
y2 = np.random.normal(loc=0.75, scale=0.1, size=100)
z2 = np.random.random(size=100) * 200

with plt.style.context('seaborn-talk'):

    fig, ax = plt.subplots(dpi=130, figsize=(3, 3))

    ax.scatter(x1, y1, s=z1, alpha=0.5)
    ax.scatter(x2, y2, s=z2, alpha=0.5)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('Scatter Plot')

    plt.show()

# %% [markdown]
# #### Histograms

# %%
np.random.seed(0)

x1 = np.random.normal(loc=0.5, scale=0.1, size=100)
x2 = np.random.normal(loc=0.75, scale=0.15, size=100)

with plt.style.context('seaborn-talk'):
    
    fig, ax = plt.subplots(dpi=130, figsize=(3, 3))

    # Create the first histogram and save the bins for later
    n, bins, patches = ax.hist(x1, alpha=0.5, ec='C0', bins=20, 
                               range=[0, 1.5])

    # Create the second histogram using the bins from the first one
    ax.hist(x2, alpha=0.5, ec='C1', bins=bins)

    ax.set_xlabel('x')
    ax.set_title('Histogram')

    plt.show()

# %% [markdown]
# #### Error bars

# %%
np.random.seed(0)

x = np.arange(-4, 5)
y = x ** 2 + 5 * x - 6 
error = np.random.random(y.size) * 10

p = np.polyfit(x, y, 3)
x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = np.polyval(p, x_fit)

with plt.style.context('seaborn-talk'):
    
    fig, ax = plt.subplots(dpi=130, figsize=(3,3))
    
    ax.errorbar(x, y, marker='o', linestyle='none', xerr=0.5, yerr=error)
    ax.plot(x_fit, y_fit, label='Polyfit')
    ax.set_title('Errorbar')
    ax.legend(loc='upper left')
    
    plt.show()

# %% [markdown]
# #### More
#
# You can find more examples here: https://matplotlib.org/gallery.

# %% [markdown]
# ## Wrapping Up
#
# Let us now wrap everything together and use NumPy and MatPlotLib to create a plot that will contain the flux of sources in a stacked image versus the median value of the fluxes of the individual frames. This figure shall use a `scatter` plot with a color that will change depending on the signal to noise calculated (defined in some unknown fashion).
#
# Then, we will create a second figure that will be used to perform the same analysis but the Y axis will contain the ratio between the fluxes from the stacked frame and the median flux of each source in the individual frames.

# %% [markdown]
# ### Reading the data
#
# The data was reduced and stored in a text file. This file can be loaded using the numpy function `np.loadtxt`. We can check the beginning of the file by using the Unix command `head` invocked using the bang (`!`) character:

# %%
# !head data/my_table.txt
# Out:
# #    X_IMAGE      Y_IMAGE    X_WORLD    Y_WORLD    FLUX_STACK        FLUX_0        FLUX_1        FLUX_2        FLUX_3        FLUX_4        MEDIAN         SNR
#  1675.624268   885.270813  50.051296  41.366915  2.939493e+07  2.873265e+07  2.889695e+07  2.916284e+07  2.895643e+07  2.884691e+07  2.892669e+07  240.665423
#  1675.514404   461.147552  50.043141  41.350870  5.865541e+06  5.817038e+06  5.812127e+06  5.829026e+06  5.819264e+06  5.804957e+06  5.815695e+06  653.499668
#  1572.794312   263.704773  50.034168  41.344886  6.194218e+07  6.200281e+07  6.857158e+07  6.196014e+07  6.025963e+07  5.676382e+07  6.110989e+07   14.247842
#   695.572144   214.694962  49.988974  41.355719  9.605618e+06  9.621454e+06  9.633023e+06  9.581749e+06  9.526921e+06  9.515865e+06  9.554335e+06  204.042266
#  1439.694946   102.391418  50.024358  41.340708  2.409045e+05  2.614427e+05  2.621096e+05  2.634221e+05  2.393407e+05  2.398817e+05  2.509956e+05   21.659586
# ...

# %% [markdown]
# We don't need to load the whole data. For the first plot, we can do it only using the `FLUX_STACK`, the `MEDIAN` and the `SNR` columns. They are the columns number 4, 10 and 11, repectively (0-indexed).

# %%
filename = 'data/my_table.txt'
flux_stack, flux_median, snr = np.loadtxt(
    filename, usecols=[4, 10, 11], unpack=True)

# %% [markdown]
# ### First Plot

# %% [markdown]
# Now we want to have a scatter plot of `flux_stack` versus `flux_median`. Let's do this using Figures and Axes. It will be useful.

# %%
fig, ax = plt.subplots()

ax.plot(flux_median, flux_stack)

plt.show()

# %% [markdown]
# ### Changing Marker and LineStyle

# %% [markdown]
# Since the data is not necesarily ordered, we might want to change the line to use a round marker instead:

# %%
fig, ax = plt.subplots()

ax.plot(flux_median, flux_stack, 'o')

plt.show()

# %% [markdown]
# Let's change the X and Y axis to a log scale for better visualization:

# %%
fig, ax = plt.subplots()

ax.plot(flux_median, flux_stack, 'o')

ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# ### Adding Labels and Title

# %% [markdown]
# Much clearer! Now let's add a title, a grid and set the labels of both X and Y axis:

# %%
fig, ax = plt.subplots()

ax.plot(flux_median, flux_stack, 'o')

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('Median of Sources on Individual Frames')
ax.set_ylabel('Flux of Sources in the Stacked Frame')
ax.set_title('Stacked Sources vs Median Fluxes')
ax.grid(alpha=0.5)

# %% [markdown]
# ### Linear Fitting
#
# The plots above confirm that the relationship between X and Y should be linear. We can check that by using `np.polyfit` and plotting the result:

# %%
fig, ax = plt.subplots()

p = np.polyfit(flux_median, flux_stack, 1)

x_fit = np.linspace(flux_median.min(), flux_median.max(), 1000)
y_fit = np.polyval(p, x_fit)

ax.loglog(flux_median, flux_stack, 'o')

ax.plot(x_fit, y_fit, '-', 
        label=u'$f(x) = {0:.2f}\cdot x + {1:.2f}$'.format(*p))

ax.legend(loc='upper left')
ax.set_xlabel('Median of Sources on Individual Frames')
ax.set_ylabel('Flux of Sources in the Stacked Frame')
ax.set_title('Stacked Sources vs Median Fluxes')
ax.grid(alpha=0.5)

plt.show()

# %% [markdown]
# ### Plotting ratio
#
# Another way to see the result above is plotting $\frac{Flux Stack}{Flux Median} \times Flux Median$ and the flux should be around 1:

# %%
fig, ax = plt.subplots()

x = flux_median
y = flux_stack / flux_median

ax.plot(x, y, 'o')
ax.set_xscale('log')

ax.set_xlabel('Median of Sources on Individual Frames')
ax.set_ylabel('Stack Flux divided by Median Flux')

ax.set_title('Ratio between Stacked Sources and Median Fluxes vs Median Fluxes')

ax.grid(alpha=0.5)

plt.show()

# %% [markdown]
# ### Adding a Violin Plot
#
# It might be interesting to see the distribution of the points in the Y direction. For that, let us recreate our figure using `plt.subplots` with two columns that will share the y-axis.

# %%
x = flux_median
y = flux_stack / flux_median

fig, axes = plt.subplots(ncols=2, sharey=True)

ax1 = axes[1]
ax1.plot(x, y, marker='o', linestyle='none', alpha=0.4)
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])

plt.show()

# %% [markdown]
# This is pretty nice but we have to scale the plots so we can see the right axes better. This can be done passing the `gridspec_kw` argument, a dictionary used to control the axes grid.

# %%
x = flux_median
y = flux_stack / flux_median

fig, axes = plt.subplots(ncols=2, sharey=True, gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
ax1.plot(x, y, marker='o', linestyle='none', alpha=0.4)
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])

fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
plt.show()

# %% [markdown]
# We can make the two plots closer to improve association between them using `fig.tight_layout`:

# %%
x = flux_median
y = flux_stack / flux_median

fig, axes = plt.subplots(ncols=2, sharey=True, gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
ax1.plot(x, y, marker='o', linestyle='none', alpha=0.4)
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])
ax2.grid(alpha=0.25)

fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
fig.tight_layout(w_pad=0)
plt.show()

# %% [markdown]
# Now the title is messed up. Let's fix that passing `rect` to the `fig.tight_layout` function:

# %%
x = flux_median
y = flux_stack / flux_median

fig, axes = plt.subplots(ncols=2, sharey=True, gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
ax1.plot(x, y, marker='o', linestyle='none', alpha=0.4)
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])
ax2.grid(alpha=0.25)

fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
fig.tight_layout(rect=[0, 0.05, 0.85, 0.95], w_pad=0)
plt.show()

# %% [markdown]
# ### Using Scatter plot

# %% [markdown]
# #### with different marker sizes

# %% [markdown]
# We can have more information by using `plt.scatter` instead of using `plt.plot`. `plt.scatter` allows passing an array to set the marker size parameter `s`:

# %%
x = flux_median
y = flux_stack / flux_median
z = snr

fig, axes = plt.subplots(figsize=(7,5), ncols=2, sharey=True, gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
ax1.scatter(x, y, s=z, marker='o', alpha=0.4)
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])
ax2.grid(alpha=0.25)

fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
fig.tight_layout(rect=[0, 0.05, 0.85, 0.95], w_pad=0)
plt.show()

# %% [markdown]
# #### with different colors
#
# Another option is to use colors instead of using marker size. This can be done passing the array to the `c` parameter instead:

# %%
x = flux_median
y = flux_stack / flux_median
z = snr

fig, axes = plt.subplots(figsize=(7,5), ncols=2, sharey=True, gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
ax1.scatter(x, y, c=z, marker='o', alpha=0.4)
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])
ax2.grid(alpha=0.25)

fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
fig.tight_layout(rect=[0, 0.05, 0.85, 0.95], w_pad=0)
plt.show()

# %% [markdown]
# If we want a logarithmic logscale, we will have to use the `matplotlib.colors` package, the `LogNorm()` function and the `norm=` parameter:

# %%
from matplotlib import colors as mcolors

x = flux_median
y = flux_stack / flux_median
z = snr

fig, axes = plt.subplots(figsize=(7,5), ncols=2, sharey=True, gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
ax1.scatter(x, y, c=z, marker='o', alpha=0.4, norm=mcolors.LogNorm())
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])
ax2.grid(alpha=0.25)

fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
fig.tight_layout(rect=[0, 0.05, 0.85, 0.95], w_pad=0)
plt.show()

# %% [markdown]
# This allows us to add a logarithmic logbar to the figure which maximizes the SNR contrast:

# %%
from matplotlib import colors as mcolors

x = flux_median
y = flux_stack / flux_median
z = snr

fig, axes = plt.subplots(figsize=(7,5), ncols=2, sharey=True, 
                         gridspec_kw={'width_ratios': [1, 15]})

ax1 = axes[1]
im1 = ax1.scatter(x, y, c=z, marker='o', alpha=0.4, norm=mcolors.LogNorm())
    
ax1.set_xscale('log')
ax1.set_xlabel('Flux median')
ax1.grid(alpha=0.25)

ax2 = axes[0]
ax2.violinplot(y, showmedians=True)
ax2.set_ylabel('Flux Stack / Flux Median')
ax2.set_xticks([])
ax2.grid(alpha=0.25)

fig.colorbar(im1, label='SNR')
fig.suptitle('Stack Flux / Median Flux vs. Median Flux')
fig.tight_layout(rect=[0, 0.05, 0.95, 0.95], w_pad=0)
plt.show()
